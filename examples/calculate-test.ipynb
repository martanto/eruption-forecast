# %%
from eruption_forecast import Calculate

# %%
calculate = Calculate(
    station="OJN",
    channel="EHN",
    start_date="2025-03-17",
    end_date="2025-03-19",
    window_size=2,
    day_to_forecast=2,
    remove_outliers=True,
    verbose=True,
    debug=True,
)
# Out:
# 2026-01-09 14:38:04.937 | INFO     | eruption_forecast.calculate:__init__:108 - ⚠️ Debug mode is ON
# 2026-01-09 14:38:04.938 | INFO     | eruption_forecast.calculate:__init__:111 - Version: 0.1.0
# 2026-01-09 14:38:04.939 | INFO     | eruption_forecast.calculate:__init__:112 - Running on 1 job(s)
# 2026-01-09 14:38:04.939 | INFO     | eruption_forecast.calculate:__init__:113 - NSLC: VG.OJN.00.EHN
# 2026-01-09 14:38:04.940 | INFO     | eruption_forecast.calculate:__init__:114 - Start Date: 2025-03-17
# 2026-01-09 14:38:04.941 | INFO     | eruption_forecast.calculate:__init__:115 - End Date: 2025-03-19
# 2026-01-09 14:38:04.941 | INFO     | eruption_forecast.calculate:__init__:116 - Total Days: 3
# 2026-01-09 14:38:04.942 | INFO     | eruption_forecast.calculate:__init__:117 - Output Directory: D:\Projects\eruption-forecast\test\output\forecast
# 2026-01-09 14:38:04.942 | INFO     | eruption_forecast.calculate:__init__:118 - Station Directory: D:\Projects\eruption-forecast\test\output\forecast\VG.OJN.00.EHN
# 2026-01-09 14:38:04.943 | INFO     | eruption_forecast.calculate:__init__:119 - Tremor Directory: D:\Projects\eruption-forecast\test\output\forecast\VG.OJN.00.EHN\tremor
# 2026-01-09 14:38:04.943 | INFO     | eruption_forecast.calculate:__init__:120 - Overwrite: False

# %%
calculate.from_sds(sds_dir=r"D:\Data\OJN").run()
# Out:
# 2026-01-09 14:38:05.064 | DEBUG    | eruption_forecast.calculate:run_job:226 - Job index 0. Date: 2025-03-17
# 2026-01-09 14:38:05.065 | DEBUG    | eruption_forecast.calculate:run_job:238 - Jobs ID: 0. Date: 2025-03-17
# 2026-01-09 14:38:05.185 | INFO     | eruption_forecast.sds:get:89 - 2025-03-17 :: Stream loaded D:\Data\OJN\2025\VG\OJN\EHN.D\VG.OJN.00.EHN.D.2025.076
# 2026-01-09 14:38:05.185 | INFO     | eruption_forecast.sds:get:90 - 2025-03-17 :: 1 trace(s) found. Total data 8639901
# 2026-01-09 14:38:05.959 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-17 :: RSAM Filtered using (0.01, 0.1)
# 2026-01-09 14:38:06.574 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-17 :: RSAM Filtered using (0.1, 2)
# 2026-01-09 14:38:07.217 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-17 :: RSAM Filtered using (2, 5)
# 2026-01-09 14:38:07.840 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-17 :: RSAM Filtered using (4.5, 8)
# 2026-01-09 14:38:08.479 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-17 :: RSAM Filtered using (8, 16)
# 2026-01-09 14:38:09.050 | DEBUG    | eruption_forecast.calculate:run_job:226 - Job index 1. Date: 2025-03-18
# 2026-01-09 14:38:09.050 | DEBUG    | eruption_forecast.calculate:run_job:238 - Jobs ID: 1. Date: 2025-03-18
# 2026-01-09 14:38:09.103 | INFO     | eruption_forecast.sds:get:89 - 2025-03-18 :: Stream loaded D:\Data\OJN\2025\VG\OJN\EHN.D\VG.OJN.00.EHN.D.2025.077
# 2026-01-09 14:38:09.103 | INFO     | eruption_forecast.sds:get:90 - 2025-03-18 :: 1 trace(s) found. Total data 8639901
# 2026-01-09 14:38:09.222 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-18 :: RSAM Filtered using (0.01, 0.1)
# 2026-01-09 14:38:09.826 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-18 :: RSAM Filtered using (0.1, 2)
# 2026-01-09 14:38:10.461 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-18 :: RSAM Filtered using (2, 5)
# 2026-01-09 14:38:11.091 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-18 :: RSAM Filtered using (4.5, 8)
# 2026-01-09 14:38:11.712 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-18 :: RSAM Filtered using (8, 16)
# 2026-01-09 14:38:12.274 | DEBUG    | eruption_forecast.calculate:run_job:226 - Job index 2. Date: 2025-03-19
# 2026-01-09 14:38:12.274 | DEBUG    | eruption_forecast.calculate:run_job:238 - Jobs ID: 2. Date: 2025-03-19
# 2026-01-09 14:38:12.323 | INFO     | eruption_forecast.sds:get:89 - 2025-03-19 :: Stream loaded D:\Data\OJN\2025\VG\OJN\EHN.D\VG.OJN.00.EHN.D.2025.078
# 2026-01-09 14:38:12.323 | INFO     | eruption_forecast.sds:get:90 - 2025-03-19 :: 1 trace(s) found. Total data 8639901
# 2026-01-09 14:38:12.447 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-19 :: RSAM Filtered using (0.01, 0.1)
# 2026-01-09 14:38:13.050 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-19 :: RSAM Filtered using (0.1, 2)
# 2026-01-09 14:38:13.671 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-19 :: RSAM Filtered using (2, 5)
# 2026-01-09 14:38:14.296 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-19 :: RSAM Filtered using (4.5, 8)
# 2026-01-09 14:38:14.922 | DEBUG    | eruption_forecast.calculate:calculate_rsam:314 - 2025-03-19 :: RSAM Filtered using (8, 16)

# %%
calculate
