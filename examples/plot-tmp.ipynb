# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime

# %%
df1 = pd.read_csv(
    r"D:\Projects\eruption-forecast\output\forecast\VG.OJN.00.EHZ\tremor\_tmp\2025-01-02.csv",
    index_col=0,
    parse_dates=True,
)

# %%
df1["rsam_f2"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
df2 = pd.read_csv(
    r"D:\Projects\whakaari-original\_tmp\_tmp_fl_00001.csv",
    index_col=0,
    parse_dates=True,
)

# %%
df2["rsam"].plot()
# Out:
# <Axes: xlabel='time'>

# %%
df1["dsar_f0-f1"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
df2["vlar"].plot()
# Out:
# <Axes: xlabel='time'>
