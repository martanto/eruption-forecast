# %%
from eruption_forecast import LabelBuilder

# %%
eruptions = [
    "2025-03-20",
    "2025-04-22",
    "2025-05-18",
    "2025-06-17",
    "2025-07-07",
    "2025-08-01",
    "2025-08-17",
]

# %%
start_date = "2025-01-01"
end_date = "2025-12-31"
window_size = 2
window_overlap = 0.75
sampling_rate = 100.0
day_to_forecast = 2

# %%
label_builder = LabelBuilder(
	start_date=start_date,
	end_date=end_date,
	window_size=window_size,
	window_overlap=window_overlap,
	sampling_rate=sampling_rate,
	day_to_forecast=day_to_forecast,
	eruption_dates=eruptions,
	verbose=True
)
# Out:
# 2026-01-16 11:51:20.381 | INFO     | eruption_forecast.label:__init__:103 - Start Date: 2025-01-01
# 2026-01-16 11:51:20.382 | INFO     | eruption_forecast.label:__init__:104 - End Date: 2025-12-31
# 2026-01-16 11:51:20.383 | INFO     | eruption_forecast.label:__init__:105 - Window Size: 2
# 2026-01-16 11:51:20.384 | INFO     | eruption_forecast.label:__init__:106 - Window Overlap: 0.75
# 2026-01-16 11:51:20.384 | INFO     | eruption_forecast.label:__init__:107 - Sampling Rate: 100.0
# 2026-01-16 11:51:20.384 | INFO     | eruption_forecast.label:__init__:108 - Day To Forecast: 2
# 2026-01-16 11:51:20.384 | INFO     | eruption_forecast.label:__init__:109 - Label File: d:\Projects\eruption-forecast\examples\output\labels\label_2025-01-01_2025-12-31_ws-2_wo-0.75_sr-100.0_dtf-2.csv

# %%
label_builder.create()
# Out:
# 2026-01-16 11:51:20.409 | INFO     | eruption_forecast.label:save:289 - Label saved to d:\Projects\eruption-forecast\examples\output\labels\label_2025-01-01_2025-12-31_ws-2_wo-0.75_sr-100.0_dtf-2.csv
# LabelBuilder(2025-01-01, 2025-12-31, 2, 0.75, 100.0, 2, ['2025-03-20', '2025-04-22', '2025-05-18', '2025-06-17', '2025-07-07', '2025-08-01', '2025-08-17'])

# %%
df_erupted = label_builder.df_erupted

# %%
label_builder.df_eruptions['2025-03-20'].index.to_list()
# Out:
# [Timestamp('2025-03-18 00:00:00'),
#  Timestamp('2025-03-18 12:00:00'),
#  Timestamp('2025-03-19 00:00:00'),
#  Timestamp('2025-03-19 12:00:00'),
#  Timestamp('2025-03-20 00:00:00'),
#  Timestamp('2025-03-20 12:00:00')]

# %%
label_builder.filepath
# Out:
# 'd:\\Projects\\eruption-forecast\\examples\\output\\labels\\label_2025-01-01_2025-12-31_ws-2_wo-0.75_sr-100.0_dtf-2.csv'
