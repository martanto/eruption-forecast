# %%
from eruption_forecast import LabelBuilder

# %%
eruptions = [
    "2025-03-20",
    "2025-04-22",
    "2025-05-18",
    "2025-06-17",
    "2025-07-07",
    "2025-08-01",
    "2025-08-17",
]

# %%
start_date = "2025-01-01"
end_date = "2025-12-24"
window_size = 2
window_overlap = 0.75
sampling_rate = 100.0
day_to_forecast = 2

# %%
label_builder = LabelBuilder(
	start_date=start_date,
	end_date=end_date,
	window_size=window_size,
	window_overlap=window_overlap,
	sampling_rate=sampling_rate,
	day_to_forecast=day_to_forecast,
	eruption_dates=eruptions,
	volcano_id="Lewotobi Laki-laki",
	verbose=True
)
# Out:
# 2026-01-19 11:45:50.498 | INFO     | eruption_forecast.label.label_builder:__init__:105 - Start Date: 2025-01-01
# 2026-01-19 11:45:50.500 | INFO     | eruption_forecast.label.label_builder:__init__:106 - End Date: 2025-12-24
# 2026-01-19 11:45:50.501 | INFO     | eruption_forecast.label.label_builder:__init__:107 - Window Size: 2
# 2026-01-19 11:45:50.501 | INFO     | eruption_forecast.label.label_builder:__init__:108 - Window Overlap: 0.75
# 2026-01-19 11:45:50.502 | INFO     | eruption_forecast.label.label_builder:__init__:109 - Sampling Rate: 100.0
# 2026-01-19 11:45:50.503 | INFO     | eruption_forecast.label.label_builder:__init__:110 - Day To Forecast: 2
# 2026-01-19 11:45:50.503 | INFO     | eruption_forecast.label.label_builder:__init__:111 - Label File: d:\Projects\eruption-forecast\examples\output\labels\label_2025-01-01_2025-12-24_ws-2_wo-0.75_sr-100.0_dtf-2.csv

# %%
label_builder
# Out:
# LabelBuilder(2025-01-01, 2025-12-24, 2, 0.75, 100.0, 2, ['2025-03-20', '2025-04-22', '2025-05-18', '2025-06-17', '2025-07-07', '2025-08-01', '2025-08-17']), Lewotobi Laki-laki

# %%
label_builder.build()
# Out:
# 2026-01-19 11:45:54.561 | INFO     | eruption_forecast.label.label_builder:save:453 - Label saved to d:\Projects\eruption-forecast\examples\output\labels\label_2025-01-01_2025-12-24_ws-2_wo-0.75_sr-100.0_dtf-2.csv
# 2026-01-19 11:45:54.567 | INFO     | eruption_forecast.label.label_builder:save_eruption_dates:381 - Eruption dates saved to d:\Projects\eruption-forecast\examples\output\labels\eruption_dates.csv
# LabelBuilder(2025-01-01, 2025-12-24, 2, 0.75, 100.0, 2, ['2025-03-20', '2025-04-22', '2025-05-18', '2025-06-17', '2025-07-07', '2025-08-01', '2025-08-17']), Lewotobi Laki-laki

# %%
df_erupted = label_builder.df_eruption

# %%
label_builder.df_eruptions['2025-03-20'].index.to_list()
# Out:
# [Timestamp('2025-03-18 00:00:00'),
#  Timestamp('2025-03-18 12:00:00'),
#  Timestamp('2025-03-19 00:00:00'),
#  Timestamp('2025-03-19 12:00:00'),
#  Timestamp('2025-03-20 00:00:00'),
#  Timestamp('2025-03-20 12:00:00')]

# %%
label_builder.filepath
# Out:
# 'd:\\Projects\\eruption-forecast\\examples\\output\\labels\\label_2025-01-01_2025-12-24_ws-2_wo-0.75_sr-100.0_dtf-2.csv'

# %%
label_builder.df_eruptions["2025-03-20"]
# Out:
#                       id  is_erupted
# datetime
# 2025-03-18 00:00:00  152           1
# 2025-03-18 12:00:00  153           1
# 2025-03-19 00:00:00  154           1
# 2025-03-19 12:00:00  155           1
# 2025-03-20 00:00:00  156           1
# 2025-03-20 12:00:00  157           1
