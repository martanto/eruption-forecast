# %%
from eruption_forecast import LabelBuilder

# %%
eruptions = [
    "2025-03-20",
    "2025-04-22",
    "2025-05-18",
    "2025-06-17",
    "2025-07-07",
    "2025-08-01",
    "2025-08-17",
]

# %%
start_date = "2025-01-01"
end_date = "2025-12-24"
window_size = 2 # in days
window_step = 12 # in hours
sampling_rate = 100.0
day_to_forecast = 2

# %%
label_builder = LabelBuilder(
    start_date=start_date,
    end_date=end_date,
    window_size=window_size,
    window_step=window_step,
    sampling_rate=sampling_rate,
    day_to_forecast=day_to_forecast,
    eruption_dates=eruptions,
    volcano_id="Lewotobi Laki-laki",
    output_dir=r"D:\Projects\eruption-forecast\examples\output\VG.OJN.00.EHN",
    verbose=True,
)
# Out:
# 2026-01-22 13:49:49.186 | INFO     | eruption_forecast.label.label_builder:__init__:112 - Start Date (YYYY-MM-DD): 2025-01-01
# 2026-01-22 13:49:49.187 | INFO     | eruption_forecast.label.label_builder:__init__:113 - End Date (YYYY-MM-DD): 2025-12-24
# 2026-01-22 13:49:49.187 | INFO     | eruption_forecast.label.label_builder:__init__:114 - Window Size (days): 2
# 2026-01-22 13:49:49.188 | INFO     | eruption_forecast.label.label_builder:__init__:115 - Window Step (hours): 12
# 2026-01-22 13:49:49.188 | INFO     | eruption_forecast.label.label_builder:__init__:116 - Sampling Rate (Hz): 100.0
# 2026-01-22 13:49:49.189 | INFO     | eruption_forecast.label.label_builder:__init__:117 - Day To Forecast (days): 2
# 2026-01-22 13:49:49.190 | INFO     | eruption_forecast.label.label_builder:__init__:118 - Volcano ID: Lewotobi Laki-laki

# %%
label_builder
# Out:
# LabelBuilder(2025-01-01, 2025-12-24, 2, 12, 100.0, 2, ['2025-03-20', '2025-04-22', '2025-05-18', '2025-06-17', '2025-07-07', '2025-08-01', '2025-08-17']), Lewotobi Laki-laki

# %%
label_builder.build()
# Out:
# 2026-01-22 13:49:49.230 | INFO     | eruption_forecast.label.label_builder:save:451 - Label saved to D:\Projects\eruption-forecast\examples\output\VG.OJN.00.EHN\labels\label_2025-01-01_2025-12-24_ws-2_step-12_sr-100.0_dtf-2.csv
# 2026-01-22 13:49:49.232 | INFO     | eruption_forecast.label.label_builder:save_eruption_dates:374 - Eruption dates saved to D:\Projects\eruption-forecast\examples\output\VG.OJN.00.EHN\labels\eruption_dates.csv
# LabelBuilder(2025-01-01, 2025-12-24, 2, 12, 100.0, 2, ['2025-03-20', '2025-04-22', '2025-05-18', '2025-06-17', '2025-07-07', '2025-08-01', '2025-08-17']), Lewotobi Laki-laki

# %%
df_erupted = label_builder.df_eruption

# %%
label_builder.df_eruptions['2025-03-20'].index.to_list()
# Out:
# [Timestamp('2025-03-18 00:00:00'),
#  Timestamp('2025-03-18 12:00:00'),
#  Timestamp('2025-03-19 00:00:00'),
#  Timestamp('2025-03-19 12:00:00'),
#  Timestamp('2025-03-20 00:00:00'),
#  Timestamp('2025-03-20 12:00:00')]

# %%
label_builder.filepath
# Out:
# 'D:\\Projects\\eruption-forecast\\examples\\output\\VG.OJN.00.EHN\\labels\\label_2025-01-01_2025-12-24_ws-2_step-12_sr-100.0_dtf-2.csv'

# %%
label_builder.df_eruptions["2025-03-20"]
# Out:
#                       id  is_erupted
# datetime
# 2025-03-18 00:00:00  152           1
# 2025-03-18 12:00:00  153           1
# 2025-03-19 00:00:00  154           1
# 2025-03-19 12:00:00  155           1
# 2025-03-20 00:00:00  156           1
# 2025-03-20 12:00:00  157           1
