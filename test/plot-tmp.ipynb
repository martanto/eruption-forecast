# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv(r"D:\Projects\eruption-forecast\output\forecast\VG.OJN.00.EHZ\tremor\_tmp\2025-01-02.csv", index_col=0, parse_dates=True)

# %%
df["rsam_2-5"]
# Out:
# datetime
# 2025-01-02 00:00:00    87.946111
# 2025-01-02 00:10:00    28.953875
# 2025-01-02 00:20:00    23.883978
# 2025-01-02 00:30:00    27.353385
# 2025-01-02 00:40:00    27.995871
#                          ...
# 2025-01-02 23:10:00    20.651188
# 2025-01-02 23:20:00    16.650816
# 2025-01-02 23:30:00    24.370134
# 2025-01-02 23:40:00    18.456058
# 2025-01-02 23:50:00    17.312879
# Name: rsam_2-5, Length: 144, dtype: float64

# %%
df["rsam_2-5"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
df = pd.read_csv(r"D:\Projects\whakaari-original\_tmp\_tmp_fl_00001.csv", index_col=0, parse_dates=True)

# %%
df["rsam"]
# Out:
# time
# 2025-01-02 00:00:00    8.807293e+10
# 2025-01-02 00:10:00    2.895883e+10
# 2025-01-02 00:20:00    2.388624e+10
# 2025-01-02 00:30:00    2.735565e+10
# 2025-01-02 00:40:00    2.799801e+10
#                            ...
# 2025-01-02 23:10:00    2.065301e+10
# 2025-01-02 23:20:00    1.665210e+10
# 2025-01-02 23:30:00    2.453398e+10
# 2025-01-02 23:40:00    1.845847e+10
# 2025-01-02 23:50:00    1.729907e+10
# Name: rsam, Length: 144, dtype: float64

# %%
df["rsam"].plot()
# Out:
# <Axes: xlabel='time'>
