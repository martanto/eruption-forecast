# %%
import pandas as pd

# %%
start_date = "2025-01-01"
end_date = "2025-01-07"
station = "OJN"
sds_dir = r"D:\Data\OJN"

# %%
dates = pd.date_range(start=start_date, end=end_date)
n_days = len(dates)

# %%
parallels = [
    (index, _date, station, sds_dir)
    for index, _date in enumerate(dates)
]

# %%
def check(index, date, station, sds_dir):
    print(index, date, station, sds_dir)

# %%
for _parallel in parallels:
    check(*_parallel)
# Out:
# 0 2025-01-01 00:00:00 OJN D:\Data\OJN
# 1 2025-01-02 00:00:00 OJN D:\Data\OJN
# 2 2025-01-03 00:00:00 OJN D:\Data\OJN
# 3 2025-01-04 00:00:00 OJN D:\Data\OJN
# 4 2025-01-05 00:00:00 OJN D:\Data\OJN
# 5 2025-01-06 00:00:00 OJN D:\Data\OJN
# 6 2025-01-07 00:00:00 OJN D:\Data\OJN
